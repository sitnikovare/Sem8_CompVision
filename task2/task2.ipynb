# %% [markdown]
# # Задание 2

# %% [markdown]
# Взять фото, которое нравится, повысить насыщенность в LAB-пространстве через А и Б компоненты

# %% [markdown]
# ### Библиотеки

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Загрузка фото в BGR

# %%
img = cv2.imread("pic.jpg")
plt.imshow(img)

# %% [markdown]
# Фото в RGB

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# Фото в LAB

# %%
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
plt.imshow(img_lab)

# %% [markdown]
# Разбивание на отдельные компоненты

# %%
_, a, b = cv2.split(img_lab)

# %% [markdown]
# Константы для изменения компонент

# %%
ma = 7 # синий
mb = 4 # желтый

# %% [markdown]
# Изменение компонент

# %%
for i in range(len(a)):
    a[i] = a[i] + ma

for i in range(len(b)):
    b[i] = b[i] + mb

# %% [markdown]
# Конвертация в BGR

# %%
new_img_lab = cv2.merge((l, a, b))
new_img_bgr = cv2.cvtColor(new_img_lab, cv2.COLOR_LAB2BGR)

# %% [markdown]
# Конвертация в RGB

# %%
new_img_rgb = cv2.cvtColor(new_img_bgr, cv2.COLOR_BGR2RGB)

# %% [markdown]
# Изначальное изобрежение

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].imshow(img)
axes[0, 0].set_title('Изначальное изображение BGR')

axes[0, 1].imshow(new_img_bgr)
axes[0, 1].set_title('Новое изображение BGR')

axes[1, 0].imshow(img_rgb)
axes[1, 0].set_title('Изначальное изображение RBG')

axes[1, 1].imshow(new_img_rgb)
axes[1, 1].set_title('Новое изображение RGB')

fig.set_figwidth(12)
fig.set_figheight(8)

plt.show()

# %% [markdown]
# Получился кот на пленку в RGB и кот под белым светом в BGR
